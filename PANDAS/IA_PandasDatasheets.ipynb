# %%
import numpy as np
import pandas as pd

np.random.seed(0)

df = pd.read_csv("base_datos_2008.csv", nrows=1000)

# %%
df
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0    2008      1           3          4   2003.0        1955   2211.0
# 1    2008      1           3          4    754.0         735   1002.0
# 2    2008      1           3          4    628.0         620    804.0
# 3    2008      1           3          4    926.0         930   1054.0
# 4    2008      1           3          4   1829.0        1755   1959.0
# ..    ...    ...         ...        ...      ...         ...      ...
# 995  2008      1           3          4   2154.0        2040   2314.0
# 996  2008      1           3          4   1322.0        1245   1444.0
# 997  2008      1           3          4    701.0         700    823.0
# 998  2008      1           3          4   1012.0        1010   1136.0
# 999  2008      1           3          4    834.0         830    955.0
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
df = df.sample(frac=0.5)

# %%
df
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 103  2008      1           3          4    650.0         650    748.0
# 141  2008      1           3          4    701.0         645    802.0
# 698  2008      1           3          4   2245.0        2125    115.0
# 261  2008      1           3          4   1118.0        1110   1225.0
# 971  2008      1           3          4   1229.0        1135   1341.0
# 819  2008      1           3          4   1305.0        1245   1558.0
# 578  2008      1           3          4   1914.0        1755   2122.0
# 264  2008      1           3          4   1049.0        1040   1509.0
# 298  2008      1           3          4   1821.0        1730   1946.0
# 654  2008      1           3          4   2014.0        2000   2143.0
# 738  2008      1           3          4   1149.0        1115   1416.0
# 823  2008      1           3          4    955.0         935   1242.0
# ...

# %%
df.dtypes
# Out:
# Year                   int64
# Month                  int64
# DayofMonth             int64
# DayOfWeek              int64
# DepTime              float64
# CRSDepTime             int64
# ArrTime              float64
# CRSArrTime             int64
# UniqueCarrier         object
# FlightNum              int64
# TailNum               object
# ActualElapsedTime    float64
# CRSElapsedTime         int64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin                object
# Dest                  object
# Distance               int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled              int64
# CancellationCode      object
# Diverted               int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# dtype: object

# %%
data = df.groupby(by=["TaxiOut"])["DepDelay", "ArrDelay"].mean()
data.head()
data.describe()
# Out:
# <ipython-input-40-ebf29a6a71e8>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data = df.groupby(by=["TaxiOut"])["DepDelay", "ArrDelay"].mean()
#         DepDelay   ArrDelay
# count  13.000000  13.000000
# mean   32.662088  25.698168
# std    15.890376  19.662144
# min    10.200000  -0.200000
# 25%    26.600000  14.333333
# 50%    28.000000  17.000000
# 75%    36.333333  34.000000
# max    66.714286  66.666667

# %%
df2 = df[np.abs(df["DepDelay"])>60]

# %%
df2
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 698  2008      1           3          4   2245.0        2125    115.0
# 578  2008      1           3          4   1914.0        1755   2122.0
# 643  2008      1           3          4   1730.0        1620   2028.0
# 389  2008      1           3          4   1556.0        1440   1804.0
# 142  2008      1           3          4   1556.0        1455   1704.0
# 706  2008      1           3          4   1901.0        1600   2113.0
# 672  2008      1           3          4   2106.0        1925      2.0
# 740  2008      1           3          4   2217.0        2110     47.0
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 698           5            WN       2786  ...    4.0      8.0          0
# 578        2005            WN       1507  ...    1.0     14.0          0
# 643        1920            WN       1484  ...    8.0     14.0          0
# ...

# %%
df3 = df[np.abs(df["DepDelay"]) == 0]

# %%
df3
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 55   2008      1           3          4    700.0         700    851.0
# 175  2008      1           3          4   1030.0        1030   1545.0
# 103  2008      1           3          4    650.0         650    748.0
# 251  2008      1           3          4    805.0         805    909.0
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 55          900            WN        449  ...    6.0      6.0          0
# 175        1545            WN        762  ...    3.0     18.0          0
# 103         750            WN        670  ...    3.0      8.0          0
# 251         905            WN        711  ...    3.0     16.0          0
#
#      CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# 55                NaN         0           NaN          NaN      NaN
# 175               NaN         0           NaN          NaN      NaN
# ...

# %%
data2 = df.groupby(by=["Time", "Origin"], as_index = False)["FlightNum","DepDelay", "ArrDelay"].mean()
